# %% [markdown]
# # 05 — Future work (Phase 2)
#
# After the tree-based pipeline is stable, **K-Nearest Neighbors** (similarity baseline) and a **small neural network** (MLP) can be trained on the **same** engineered features and `train_test_split` with identical metrics (F1, precision, recall, confusion matrices).
#
# Sketch:
#
# ```python
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.neural_network import MLPClassifier
# # Same X, y preprocessor as DecisionTree/RandomForest pipeline
# ```
#
# This notebook is intentionally minimal until Phase 1 results are finalized.

# %%
print("Phase 2: add KNN + MLP comparison here.")
